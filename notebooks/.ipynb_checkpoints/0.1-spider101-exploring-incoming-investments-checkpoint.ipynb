# %%
import os, sys
sys.path.insert(0, os.environ['PROJECT_PATH'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geoplotlib
sns.set()
# %matplotlib inline

# %%
from config.resources import path_to

# %%
path_to_data = path_to['filtered_data'].format('series_a', 'angel_group')
filtered_investments_df = pd.read_csv(path_to_data, encoding='latin1')

# %%
filtered_investments_df.columns
# Out:
# Index([u'funding_round_uuid', u'investor_uuid', u'is_lead_investor',
#        u'investor_name', u'country_code_investors', u'state_code_investors',
#        u'city_investors', u'investor_type', u'company_uuid',
#        u'country_code_investees', u'state_code_investees', u'city_investees',
#        u'investment_type', u'raised_amount_usd', u'latitude_investors',
#        u'longitude_investors', u'confidence_investors', u'msa_name_investors',
#        u'msa_code_investors', u'latitude_investees', u'longitude_investees',
#        u'confidence_investees', u'msa_name_investees', u'msa_code_investees'],
#       dtype='object')

# %%
incoming_investments_fields = ['company_uuid', 'city_investees', 'state_code_investees', 'latitude_investees', 'longitude_investees', 'msa_name_investees', 'msa_code_investees', 'raised_amount_usd' ]
incoming_investments_df = filtered_investments_df[ incoming_investments_fields ]
incoming_investments_df.head()
# Out:
#                            company_uuid city_investees state_code_investees  \
# 0  ff62df1f-c0d7-3d33-7531-22a507fffffc          Solon                   OH
# 1  52b1bf48-4441-b9e3-63af-1b098d7bc911      Cleveland                   OH
# 2  55e56cd3-82d2-c782-4609-c1fcb2924e36      Cleveland                   OH
# 3  7e66bb08-5d37-d5f7-c432-32c950893b9f      Cleveland                   OH
# 4  fb77b550-5a58-a0be-eb32-80661325d5d7      Cleveland                   OH
#
#    latitude_investees  longitude_investees               msa_name_investees  \
# 0           41.387119           -81.434402  Cleveland-Elyria, OH Metro Area
# 1           41.504730           -81.690742  Cleveland-Elyria, OH Metro Area
# 2           41.504730           -81.690742  Cleveland-Elyria, OH Metro Area
# 3           41.504730           -81.690742  Cleveland-Elyria, OH Metro Area
# 4           41.504730           -81.690742  Cleveland-Elyria, OH Metro Area
#
#    msa_code_investees  raised_amount_usd
# 0             17460.0           500000.0
# 1             17460.0          3400000.0
# 2             17460.0          2350000.0
# 3             17460.0                NaN
# 4             17460.0          3500000.0

# %%
# drop duplicate rows and rows with NaN values
incoming_investments_df = incoming_investments_df.dropna().drop_duplicates()

# %% [markdown]
# ## Exploring by state

# %%
incoming_investments_by_state = incoming_investments_df.groupby('state_code_investees')

# %%
incoming_investments_by_state.describe()['raised_amount_usd'].head()
# Out:
#                       count          mean           std        min        25%  \
# state_code_investees
# AR                      1.0  5.000000e+06           NaN  5000000.0  5000000.0
# AZ                      6.0  2.418833e+06  2.613279e+06   200000.0  1003250.0
# CA                    227.0  6.463337e+06  9.326315e+06   209000.0  1702895.0
# CO                     10.0  3.916838e+06  2.696323e+06   750000.0  1537500.0
# CT                      7.0  1.051000e+07  1.331112e+07  2370000.0  3800000.0
#
#                             50%        75%          max
# state_code_investees
# AR                    5000000.0  5000000.0    5000000.0
# AZ                    1881500.0  2225000.0    7500000.0
# CA                    4000000.0  7870000.0  102000000.0
# CO                    3585000.0  6349594.0    7700000.0
# CT                    5000000.0  9300000.0   40000000.0

# %%
incoming_investments_mean_by_state = incoming_investments_by_state.mean()
plt.subplots(figsize=(20,15))
ax = sns.barplot(x=incoming_investments_mean_by_state.index, y=incoming_investments_mean_by_state['raised_amount_usd'], 
              data=incoming_investments_mean_by_state)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
print

# %%
incoming_investments_by_msa = incoming_investments_df.groupby('msa_name_investees')

# %%
incoming_investments_by_msa.describe()['raised_amount_usd'].head()
# Out:
#                                               count          mean  \
# msa_name_investees
# Akron, OH Metro Area                            1.0  3.100000e+06
# Ann Arbor, MI Metro Area                        7.0  2.930000e+06
# Atlanta-Sandy Springs-Roswell, GA Metro Area    4.0  1.675000e+06
# Austin-Round Rock, TX Metro Area               28.0  4.656500e+06
# Bakersfield, CA Metro Area                      1.0  1.500000e+06
#
#                                                        std        min  \
# msa_name_investees
# Akron, OH Metro Area                                   NaN  3100000.0
# Ann Arbor, MI Metro Area                      1.861711e+06   700000.0
# Atlanta-Sandy Springs-Roswell, GA Metro Area  7.675719e+05   800000.0
# Austin-Round Rock, TX Metro Area              9.465554e+06   100000.0
# Bakersfield, CA Metro Area                             NaN  1500000.0
#
#                                                     25%        50%        75%  \
# msa_name_investees
# Akron, OH Metro Area                          3100000.0  3100000.0  3100000.0
# Ann Arbor, MI Metro Area                      1780000.0  2000000.0  4125000.0
# Atlanta-Sandy Springs-Roswell, GA Metro Area  1175000.0  1700000.0  2200000.0
# Austin-Round Rock, TX Metro Area               338750.0  1500000.0  5375000.0
# Bakersfield, CA Metro Area                    1500000.0  1500000.0  1500000.0
#
#                                                      max
# msa_name_investees
# Akron, OH Metro Area                           3100000.0
# Ann Arbor, MI Metro Area                       6000000.0
# Atlanta-Sandy Springs-Roswell, GA Metro Area   2500000.0
# Austin-Round Rock, TX Metro Area              49000000.0
# Bakersfield, CA Metro Area                     1500000.0

# %%
incoming_investments_mean_by_msa = incoming_investments_by_msa.mean()
plt.subplots(figsize=(20,15))
ax = sns.barplot(x=incoming_investments_mean_by_msa.index, y=incoming_investments_mean_by_msa['raised_amount_usd'], 
              data=incoming_investments_mean_by_msa)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
print

# %%
incoming_investments_loc_df = incoming_investments_df[ ['latitude_investees', 'longitude_investees']]
geoplotlib.dot()
